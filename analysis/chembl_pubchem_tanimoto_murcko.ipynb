# %%
#combine pubchem and chembl data set
import pandas as pd


chembl = pd.read_csv('/home/sliu/cyp_related_coding/RF_CYP19/dataset_prep/chembl/IC50_pChembl_value_preprocessed.csv')
pubchem = pd.read_csv('/home/sliu/cyp_related_coding/RF_CYP19/dataset_prep/pubchem/merged_active_inactive_Pubchem_preprocessed.csv')

# %%
pubchem = pubchem.rename(columns={'PUBCHEM_ACTIVITY_OUTCOME': 'activity_classification'})
pubchem = pubchem.rename(columns={'PUBCHEM_SID': 'id'})
chembl = chembl.rename(columns={'Molecule ChEMBL ID': 'id'})
chembl = chembl.drop('pChEMBL Value', axis=1)

# %%
print(len(pubchem))
# Out:
# 3196

# %%
print(len(chembl))
# Out:
# 1500

# %%
pubchem['preprocessedSmiles'] = pubchem['preprocessedSmiles'].str.replace("@", "")
pubchem.drop_duplicates('preprocessedSmiles',inplace=True)
print(len(pubchem))
# Out:
# 3178

# %%
chembl['preprocessedSmiles'] = chembl['preprocessedSmiles'].str.replace("@", "")
chembl.drop_duplicates('preprocessedSmiles',inplace=True)
print(len(chembl))
# Out:
# 1465

# %%
chembl
# Out:
#                                     preprocessedSmiles             id
# 0                        Brc1ccc2c(c1)CCC2=Cc1c[nH]cn1   CHEMBL174579
# 1                 O=c1cc(-c2ccc(O)cc2)oc2cc(O)cc(O)c12       CHEMBL28
# 2                        COc1ccc2cc(-c3cccnc3)ccc2c1Br   CHEMBL196328
# 3           CC[CH]1CC2C(CCC3(C)C(O)CCC23)C2(C)CCCC=C12   CHEMBL306022
# 4                COc1ccc2nc3cc(Cl)ccc3c(Nc3cccnc3)c2c1   CHEMBL495567
# ...                                                ...            ...
# 1495          CCC(c1ccc(C#N)cc1)(c1ccc(C#N)cc1)n1cncn1   CHEMBL224462
# 1496         CCC#CCOc1ccc2c(=O)c3ccc(Cn4ccnc4)cc3oc2c1  CHEMBL4632445
# 1497         CCC#CCOc1cc(Cn2ccnc2)c2oc3ccccc3c(=O)c2c1  CHEMBL4634777
# 1498  Nc1ccc(C(=Cn2ccnc2)C(c2ccc(O)cc2)c2ccc(O)cc2)cc1  CHEMBL4755831
# 1499  Oc1ccc(C(=Cn2ccnc2)C(c2ccc(O)cc2)c2ccc(O)cc2)cc1  CHEMBL4780337
#
# [1465 rows x 2 columns]

# %%
pubchem
# Out:
#                                      preprocessedSmiles           id  \
# 0          CN1CCN(CCCN2c3ccccc3Sc3ccc(C(F)(F)F)cc32)CC1  144203568.0
# 1                           Oc1ccc(Cl)cc1Sc1cc(Cl)ccc1O  144203582.0
# 2          CC[C]12CCCN3CCc4c(n(c5ccccc45)C(=O)C1)[CH]32  144203611.0
# 3                Clc1ccccc1C(c1ccccc1)(c1ccccc1)n1ccnc1  144203662.0
# 4     Fc1ccc(C(OCCN2CCN(CCCc3ccccc3)CC2)c2ccc(F)cc2)cc1  144203676.0
# ...                                                 ...          ...
# 3191  CS(=O)(=O)c1ccc(C(=O)C2C(=O)CCCC2=O)c([N+](=O)...  144214011.0
# 3192                         O=C(O)COc1nc(Cl)c(Cl)cc1Cl  144214034.0
# 3193             COc1ccc(C(c2ccc(OC)cc2)C(Cl)(Cl)Cl)cc1  144214036.0
# 3194                     CCCCC(CC)COC(=O)c1ccccc1C(=O)O  144214037.0
# 3195           CCCCC(CC)COC(=O)c1ccccc1C(=O)OCC(CC)CCCC  144214045.0
#
#      activity_classification
# 0                     Active
# 1                     Active
# 2                     Active
# ...

# %%
chembl.dropna(subset = ['preprocessedSmiles'],inplace=True)
chembl
# Out:
#                                     preprocessedSmiles             id
# 0                        Brc1ccc2c(c1)CCC2=Cc1c[nH]cn1   CHEMBL174579
# 1                 O=c1cc(-c2ccc(O)cc2)oc2cc(O)cc(O)c12       CHEMBL28
# 2                        COc1ccc2cc(-c3cccnc3)ccc2c1Br   CHEMBL196328
# 3           CC[CH]1CC2C(CCC3(C)C(O)CCC23)C2(C)CCCC=C12   CHEMBL306022
# 4                COc1ccc2nc3cc(Cl)ccc3c(Nc3cccnc3)c2c1   CHEMBL495567
# ...                                                ...            ...
# 1495          CCC(c1ccc(C#N)cc1)(c1ccc(C#N)cc1)n1cncn1   CHEMBL224462
# 1496         CCC#CCOc1ccc2c(=O)c3ccc(Cn4ccnc4)cc3oc2c1  CHEMBL4632445
# 1497         CCC#CCOc1cc(Cn2ccnc2)c2oc3ccccc3c(=O)c2c1  CHEMBL4634777
# 1498  Nc1ccc(C(=Cn2ccnc2)C(c2ccc(O)cc2)c2ccc(O)cc2)cc1  CHEMBL4755831
# 1499  Oc1ccc(C(=Cn2ccnc2)C(c2ccc(O)cc2)c2ccc(O)cc2)cc1  CHEMBL4780337
#
# [1465 rows x 2 columns]

# %%
pubchem.dropna(subset = ['preprocessedSmiles'],inplace=True)
pubchem
# Out:
#                                      preprocessedSmiles           id  \
# 0          CN1CCN(CCCN2c3ccccc3Sc3ccc(C(F)(F)F)cc32)CC1  144203568.0
# 1                           Oc1ccc(Cl)cc1Sc1cc(Cl)ccc1O  144203582.0
# 2          CC[C]12CCCN3CCc4c(n(c5ccccc45)C(=O)C1)[CH]32  144203611.0
# 3                Clc1ccccc1C(c1ccccc1)(c1ccccc1)n1ccnc1  144203662.0
# 4     Fc1ccc(C(OCCN2CCN(CCCc3ccccc3)CC2)c2ccc(F)cc2)cc1  144203676.0
# ...                                                 ...          ...
# 3191  CS(=O)(=O)c1ccc(C(=O)C2C(=O)CCCC2=O)c([N+](=O)...  144214011.0
# 3192                         O=C(O)COc1nc(Cl)c(Cl)cc1Cl  144214034.0
# 3193             COc1ccc(C(c2ccc(OC)cc2)C(Cl)(Cl)Cl)cc1  144214036.0
# 3194                     CCCCC(CC)COC(=O)c1ccccc1C(=O)O  144214037.0
# 3195           CCCCC(CC)COC(=O)c1ccccc1C(=O)OCC(CC)CCCC  144214045.0
#
#      activity_classification
# 0                     Active
# 1                     Active
# 2                     Active
# ...

# %%
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.DataStructs.cDataStructs import TanimotoSimilarity
import matplotlib.pyplot as plt
import numpy as np


# load dataset A and calculate Morgan fingerprints
#datasetA = [...]  # list of SMILES strings
molA = [Chem.MolFromSmiles(smiles) for smiles in chembl['preprocessedSmiles']]
fpsA = [AllChem.GetMorganFingerprintAsBitVect(m, 2, nBits=2048) for m in molA]

# load dataset B and calculate Morgan fingerprints
#datasetB = [...]  # list of SMILES strings
molB = [Chem.MolFromSmiles(smiles) for smiles in pubchem['preprocessedSmiles']]
fpsB = [AllChem.GetMorganFingerprintAsBitVect(m, 2, nBits=2048) for m in molB]

# calculate Tanimoto similarity for each pair of compounds
max_scores = []
for fpA in fpsA:
    max_score = 0
    for fpB in fpsB:
        score = TanimotoSimilarity(fpA, fpB)
        if score > max_score:
            max_score = score
    max_scores.append(max_score)

# print the list of max scores
print(max_scores)
print(len(max_scores))

# calculate cumulative histogram of max scores
counts, bin_edges = np.histogram(max_scores, bins=100, range=(0, 1), density=True)
cumulative = np.cumsum(counts)
total = cumulative[-1]
cumulative_percentage = cumulative/ total * 100  # Multiply by 100 to convert to percentage
bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2
# Out:
# [0.21951219512195122, 1.0, 0.2909090909090909, 0.46551724137931033, 0.48484848484848486, 0.3064516129032258, 0.30612244897959184, 0.3492063492063492, 0.3508771929824561, 0.5306122448979592, 0.36363636363636365, 0.3283582089552239, 0.5531914893617021, 0.2830188679245283, 0.5283018867924528, 0.26153846153846155, 0.49019607843137253, 0.5084745762711864, 0.2972972972972973, 0.5531914893617021, 0.3283582089552239, 0.24691358024691357, 0.390625, 0.25675675675675674, 0.2916666666666667, 0.2608695652173913, 0.30434782608695654, 0.4067796610169492, 0.3103448275862069, 0.32941176470588235, 0.328125, 0.3409090909090909, 0.39622641509433965, 0.3387096774193548, 1.0, 0.22641509433962265, 0.2857142857142857, 0.3111111111111111, 0.24390243902439024, 0.2898550724637681, 0.2777777777777778, 0.3125, 0.3023255813953488, 0.4074074074074074, 0.288135593220339, 0.39285714285714285, 0.3, 0.2916666666666667, 0.28, 0.41818181818181815, 0.35294117647058826, 0.39285714285714285, 0.3898305084745763, 0.283582089
# ...

# %%
# plot the histogram
fig = plt.figure(dpi=300)
plt.plot(bin_centers, cumulative, drawstyle='steps-post')
plt.xlabel('Max Tanimoto Score', fontsize=16)
plt.ylabel('Cumulative Frequency (%)', fontsize=16)
plt.rcParams['font.family'] = 'STIXGeneral'
plt.rcParams['figure.figsize'] = 5, 5
#plt.title('Distribution of Max Tanimoto Scores', fontsize=14)
plt.figure(dpi=300)
plt.rcParams['font.family'] = 'STIXGeneral'
plt.show()

# %%
#reverse
# calculate Tanimoto similarity for each pair of compounds
max_scores2 = []
for fpB in fpsB:
    max_score2 = 0
    for fpA in fpsA:
        score = TanimotoSimilarity(fpA, fpB)
        if score > max_score2:
            max_score2 = score
    max_scores2.append(max_score2)

# print the list of max scores
print(max_scores2)
print(len(max_scores2))

# calculate cumulative histogram of max scores
counts, bin_edges = np.histogram(max_scores2, bins=100, range=(0, 1), density=True)
cumulative = np.cumsum(counts)
total = cumulative[-1]
cumulative_percentage = cumulative/ total * 100  # Multiply by 100 to convert to percentage
bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2

# plot the histogram
plt.plot(bin_centers, cumulative, drawstyle='steps-post')
plt.xlabel('Max Tanimoto Score')
plt.ylabel('Cumulative Frequency (%)')
plt.title('Distribution of Max Tanimoto Scores')
plt.show()
# Out:
# [0.22535211267605634, 0.3333333333333333, 0.21739130434782608, 1.0, 0.2542372881355932, 0.24444444444444444, 0.21518987341772153, 0.4727272727272727, 0.3, 0.29850746268656714, 0.20512820512820512, 0.21621621621621623, 0.11904761904761904, 0.265625, 0.2857142857142857, 0.25806451612903225, 0.22807017543859648, 0.32786885245901637, 0.265625, 1.0, 0.7551020408163265, 0.3709677419354839, 0.5272727272727272, 0.2602739726027397, 0.6842105263157895, 1.0, 0.24285714285714285, 0.3088235294117647, 0.2876712328767123, 0.2, 0.25, 0.5675675675675675, 0.7872340425531915, 0.22580645161290322, 0.2261904761904762, 0.1956521739130435, 0.2222222222222222, 0.2463768115942029, 0.7, 0.25, 0.25333333333333335, 0.22105263157894736, 0.25675675675675674, 0.25, 0.2153846153846154, 0.21782178217821782, 0.3125, 0.3617021276595745, 0.2777777777777778, 0.13114754098360656, 0.1794871794871795, 0.22448979591836735, 0.23404255319148937, 0.3023255813953488, 0.2631578947368421, 0.2545454545454545, 0.18181818181818182, 
# ...

# %%
from rdkit.Chem.Scaffolds import MurckoScaffold
from rdkit.Chem import Descriptors
from collections import Counter

# Generate Murcko scaffolds for each compound in your data set

scaffolds_rdkitobject = [MurckoScaffold.GetScaffoldForMol(mol) for mol in molA]
scaffolds_rdkitobject
# Out:
# ...
#  ...]

# %%
scaffolds = [Chem.rdmolfiles.MolToSmiles(m) for m in scaffolds_rdkitobject if m is not None]

print(scaffolds)
print(len(scaffolds))
# Out:
# ['C(=C1CCc2ccccc21)c1c[nH]cn1', 'O=c1cc(-c2ccccc2)oc2ccccc12', 'c1cncc(-c2ccc3ccccc3c2)c1', 'C1=C2CCC3C4CCCC4CCC3C2CCC1', 'c1cncc(Nc2c3ccccc3nc3ccccc23)c1', 'c1ccc(Cc2cncc3ccccc23)cc1', 'c1ccc(C(=NNc2ccnnc2)c2ccccc2)cc1', 'O=c1c(-c2ccccc2)c(-n2cncn2)oc2ccccc12', 'c1ccc(C(c2cc3ccccc3o2)n2cncn2)cc1', 'c1ccc(C(c2cccnc2)c2cc3ccccc3o2)cc1', 'c1ccc(C(c2ccc3c(c2)OCO3)n2ccnc2)cc1', 'O=c1c(-c2ccccc2)c(SCc2cccnc2)oc2ccccc12', 'O=C1CCC2C1CCC1C3CCC=CC3=CCC21', 'c1ccc(-c2csc(-c3ncccn3)n2)cc1', 'O=C1CCC2C1CCC1C3CCCCC3=CCC21', 'c1ccc(-c2csc(-c3ncccn3)n2)cc1', 'O=C1CCC2C1CCC1C3CCCC=C3CCC21', 'O=C1C=CC2C(=CCC3C2CCC2C(=O)CCC23)C1', 'O=c1ccc2ccccc2[nH]1', 'O=C1CCC2C1CCC1C3CCCCC3=CCC21', 'O=c1cc(Cn2ccnc2)c2ccc(Oc3ccccc3)cc2o1', 'O=c1cc(Cn2ccnc2)c2ccc(OCc3ccccc3)cc2o1', 'O=C1CCC2C1CCC1C3CCCC=C3CCC21', 'O=c1cc(Cn2ccnc2)c2ccc(OCc3ccccc3)cc2o1', 'O=c1cc(Cn2ccnc2)c2ccc(Oc3ccccc3)cc2o1', 'O=c1ccc2ccccc2[nH]1', 'O=c1ccc2ccccc2[nH]1', 'c1ccc2c(c1)CCC1C(c3ccncc3)C21', 'c1ccc2c(c1)CCC1C(c3ccncc3)C21', 'O=C1CC(c2c
# ...

# %%
# Calculate the number of unique Murcko scaffolds in your data set
unique_scaffolds = set(scaffolds)
num_scaffolds = len(unique_scaffolds)
scaffold_counts = Counter(scaffolds)

filtered_counts = {k: v for k, v in scaffold_counts.items() if v > 10}
sorted_counts = {k: v for k, v in sorted(filtered_counts.items(), key=lambda item: item[1], reverse=True)}
for k, v in sorted_counts.items():
    print(k, v)
# Out:
# c1ccc(CN(c2ccccc2)n2cnnc2)cc1 40
# O=C1CCC(c2ccncc2)C(=O)N1 30
# c1ccc(-c2cccc(Cn3cncn3)c2)cc1 28
# O=S(=O)(NCCc1c(C(c2ccccc2)c2[nH]c3ccccc3c2CCNS(=O)(=O)c2ccccc2)[nH]c2ccccc12)c1ccccc1 26
# O=C1CC(c2ccccc2)Oc2ccccc21 25
# C(=C(c1ccccc1)c1ccccc1)c1ccccc1 25
# O=C1CCC2C1CCC1C3CCCC=C3CCC21 24
# O=C1CCC2C(=CCC3C4CCC(=O)C4CCC23)C1 22
# O=S(=O)(c1ccccc1)N1CCCC(Cn2ccnc2)C1 21
# c1ccc(C(c2ccccc2)n2cncn2)cc1 20
# O=c1cc(Cn2ccnc2)c2ccc(OCc3ccccc3)cc2o1 19
# c1ccc(COc2ccccc2)cc1 19
# c1ccc(-n2c(Cn3ccnc3)cc3ccccc32)cc1 19
# O=C1C=CC2C(=CCC3C2CCC2C(=O)CCC23)C1 17
# O=C1CCC2C1CCC1C3CCCCC3=CCC21 14
# O=c1c2ccccc2oc2cccc(Cn3ccnc3)c12 14
# c1ccc(CN(c2cccc(-c3ccccc3)c2)n2cnnc2)cc1 14
# O=S(=O)(NCc1cccc(CNS(=O)(=O)c2ccccc2)c1)c1ccccc1 13
# c1ccc(C(c2cc3ccccc3o2)n2cncn2)cc1 12
# c1ccc(-c2csc(-c3ncccn3)n2)cc1 12
# c1ccc(OCc2cn(C(c3ccccc3)c3ccccc3)nn2)cc1 12
# c1ccc(Cn2cc(COc3ccccc3)nn2)cc1 12
# c1ccc(CN(Cc2ccc(-c3ccccc3)cc2)n2ccnc2)cc1 12
# O=c1cc(Cn2ccnc2)c2ccc(Oc3ccccc3)cc2o1 11
# ...

# %%
# Plot the histogram of scaffold diversity
fig = plt.figure(dpi=300)
plt.rcParams['font.family'] = 'STIXGeneral'
plt.rcParams['figure.figsize'] = 5, 5
plt.bar(range(len(sorted_counts)), list(sorted_counts.values()))
plt.xticks(range(len(sorted_counts)), list(range(1,len(sorted_counts) +1)), rotation=90)
plt.xlabel('Murcko Scaffold (ChEMBL) ', fontsize=16)
plt.ylabel('Number of Compounds', fontsize=16)
plt.ylim((0, 50))

plt.xlim((-1, 30))
plt.figure(figsize=(100, 4))
plt.show()

# %%
scaffolds_rdkitobject2 = [MurckoScaffold.GetScaffoldForMol(mol) for mol in molB]
scaffolds2 = [Chem.rdmolfiles.MolToSmiles(m) for m in scaffolds_rdkitobject2]

scaffolds2 = [item for item in scaffolds2 if item.strip()]
#mw = [Descriptors.MolWt(mol) for mol in molA]

# Calculate the number of unique Murcko scaffolds in your data set
unique_scaffolds = set(scaffolds2)
 
unique_scaffolds = [item for item in unique_scaffolds if item.strip()]
unique_scaffolds
# Out:
# ['O=C(C1CCCCC1)N1CC(=O)N2CCc3ccccc3C2C1',
#  'O=c1cc(-c2ccccc2)nc[nH]1',
#  'C1CCC2NCCC2C1',
#  'O=C(NC1CCc2ccccc21)C(CCCN1CCN(Cc2cccnc2)CC1)Cc1ccccc1',
#  'C(=CSSCC1CCCO1)NCc1cncnc1',
#  'C1=C2CCCCC2C2CCC3C(c4cccnc4)=CCC3C2C1',
#  'c1ccc(NCc2cnc3ncncc3n2)cc1',
#  'N=C1C=CC(=C(c2ccccc2)c2ccccc2)C=C1',
#  'O=c1[nH]cc(Cc2ccc(OCCc3ccccn3)cc2)s1',
#  'c1ccc([SH+]c2ccccc2)cc1',
#  'O=c1c2ccccc2c(=O)c2c1ccc1[nH]c3c(ccc4c(=O)c5ccccc5c(=O)c43)[nH]c12',
#  'O=C(OC1CN2CCC1CC2)N1CCc2ccccc2C1c1ccccc1',
#  'C1CCC(OC2CCCC(OC3CCCCO3)C2)OC1',
#  'c1ccc(OCCNc2ccncc2)cc1',
#  'C1=CCC=C1',
#  'c1ccncc1',
#  'O=C(OC1CC2CCC(C1)N2)c1ccccc1',
#  'O=C1CCC2C(=CCC3=C2C=CC2CCCC32)C1',
#  'c1ccc(C2CNCCc3ccccc32)cc1',
#  'O=C1Nc2ccccc2Nc2ccccc21',
#  'N=C(C(=O)NC1C(=O)N2C=C(C[n+]3ccc[nH]3)CSC12)c1cscn1',
#  'c1ccc(OC2CCCCO2)cc1',
#  'O=c1[nH]ccn1N=Cc1ccc(-c2ccccc2)o1',
#  'O=C(NCCNC(=O)c1cccnc1)c1cccnc1',
#  'O=C(CCc1ccccc1)NCC(=O)OCc1ccccc1',
#  'c1ccc(C(Cn2cncn2)Cn2cncn2)cc1',
# ...

# %%
num_scaffolds = len(unique_scaffolds)
scaffold_counts = Counter(scaffolds2)

filtered_counts = {k: v for k, v in scaffold_counts.items() if v > 10}
sorted_counts = {k: v for k, v in sorted(filtered_counts.items(), key=lambda item: item[1], reverse=True)}
# Plot the histogram of scaffold diversity

# Plot the histogram of scaffold diversity
fig = plt.figure(dpi=300)
plt.rcParams['font.family'] = 'STIXGeneral'
plt.rcParams['figure.figsize'] = 5, 5
plt.bar(range(len(sorted_counts)), list(sorted_counts.values()))
plt.xticks(range(len(sorted_counts)), [chr(i + 64) for i in range(1,len(sorted_counts) +1)], rotation=90)


plt.xlabel('Murcko Scaffold (PubChem BioAssay)', fontsize=16)
plt.ylabel('Number of Compounds', fontsize=16)
plt.ylim((0, 350))

plt.xlim((-1, 30))
plt.figure(figsize=(100, 4))
plt.show()

# %%
dataframe = pd.concat([chembl, pubchem], ignore_index=True)
dataframe['activity_classification'] = dataframe['activity_classification'].str.capitalize()
dataframe
# Out:
#                                      preprocessedSmiles            id  \
# 0                         Brc1ccc2c(c1)CCC2=Cc1c[nH]cn1  CHEMBL174579
# 1                  O=c1cc(-c2ccc(O)cc2)oc2cc(O)cc(O)c12      CHEMBL28
# 2                         COc1ccc2cc(-c3cccnc3)ccc2c1Br  CHEMBL196328
# 3            CC[CH]1CC2C(CCC3(C)C(O)CCC23)C2(C)CCCC=C12  CHEMBL306022
# 4                 COc1ccc2nc3cc(Cl)ccc3c(Nc3cccnc3)c2c1  CHEMBL495567
# ...                                                 ...           ...
# 4638  CS(=O)(=O)c1ccc(C(=O)C2C(=O)CCCC2=O)c([N+](=O)...   144214011.0
# 4639                         O=C(O)COc1nc(Cl)c(Cl)cc1Cl   144214034.0
# 4640             COc1ccc(C(c2ccc(OC)cc2)C(Cl)(Cl)Cl)cc1   144214036.0
# 4641                     CCCCC(CC)COC(=O)c1ccccc1C(=O)O   144214037.0
# 4642           CCCCC(CC)COC(=O)c1ccccc1C(=O)OCC(CC)CCCC   144214045.0
#
#      activity_classification
# 0                        NaN
# 1                        NaN
# 2                        NaN
# ...

# %%
overlap = dataframe.drop_duplicates(subset=['preprocessedSmiles'])
duplicates_df = dataframe[dataframe.duplicated(subset=['preprocessedSmiles'], keep=False)]
len(overlap)
duplicates_df
overlap.to_csv('combined.csv', index=False)

# %%
from rdkit import Chem
from rdkit.Chem import Draw
duplicates = [Chem.MolFromSmiles(mol) for mol in duplicates_df.preprocessedSmiles]
Chem.Draw.MolsToGridImage(duplicates, molsPerRow=5, legends=[str(i) for i in range(len(duplicates))])

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

from physicochem_properties_for_pca import *

# %%
get_physicochemical_properties(overlap,'preprocessedSmiles')
get_further_physicochemical_properties(overlap)
overlap
# Out:
# /home/sliu/miniconda3/envs/ringsys/lib/python3.8/site-packages/rdkit/Chem/PandasTools.py:425: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame[molCol] = frame[smilesCol].map(Chem.MolFromSmiles)
# Start calculcating parameters.
# /home/sliu/cyp_related_coding/RF_CYP19/chemical_space_compare/physicochem_properties_for_pca.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   molDF['N'] = molDF['Molecule'].apply(get_molecule_composition, args=(7,))
# ...

# %%
overlap.columns
# Out:
# Index(['preprocessedSmiles', 'id', 'activity_classification', 'Molecule', 'N',
#        'O', 'chiral', 'MW', 'heavy_atoms', 'h_acc', 'h_don', 'logP', 'TPSA',
#        'numAro', 'formalCharge', 'numRings', 'frac_csp3', 'S', 'nHalogens',
#        'MR'],
#       dtype='object')

# %%
featureList = []
for column in overlap.columns:
    if column not in ['id', 'activity_classification', 'preprocessedSmiles', 'Molecule']:
        featureList.append(column)
featureList
# Out:
# ['N',
#  'O',
#  'chiral',
#  'MW',
#  'heavy_atoms',
#  'h_acc',
#  'h_don',
#  'logP',
#  'TPSA',
#  'numAro',
#  'formalCharge',
#  'numRings',
#  'frac_csp3',
#  'S',
#  'nHalogens',
#  'MR']

# %%
x = overlap.loc[:, featureList].values
y = overlap.loc[:, ['activity_classification']].values

x = StandardScaler().fit_transform(x)

pca = PCA(n_components=2)

principalComponents = pca.fit_transform(x)

variance = pca.explained_variance_ratio_
principalDF = pd.DataFrame(data=principalComponents, columns=['PC1', 'PC2'])

pcaDF = pd.concat([principalDF, overlap[['activity_classification']], dataframe[['preprocessedSmiles']], dataframe[['id']]], axis=1)

loadings = pd.DataFrame(pca.components_.T, columns=['PC1', 'PC2'], index=featureList)
print(loadings)
# Out:
#                    PC1       PC2
# N             0.167532  0.251449
# O             0.348122 -0.218164
# chiral        0.223376 -0.306538
# MW            0.353981  0.133009
# heavy_atoms   0.365927  0.166216
# h_acc         0.372515 -0.064376
# h_don         0.292429 -0.185690
# logP         -0.123866  0.296429
# TPSA          0.377098 -0.106624
# numAro        0.068934  0.538212
# formalCharge -0.018264  0.025101
# numRings      0.184090  0.284950
# frac_csp3     0.031428 -0.433397
# S             0.112521  0.093600
# nHalogens    -0.058789  0.042687
# MR            0.322080  0.205216

# %%
#plot_pca
def plot_pca(pcaDF,variance,databases,colors):
    plt.rcParams['font.family'] = 'STIXGeneral'
    plt.rcParams['figure.figsize'] = 5, 5
    fig = plt.figure(dpi=300)
    axes = fig.add_subplot()
    axes.set_xlabel('PC1 ({:.2%})'.format(variance[0]), fontsize=16)
    axes.set_ylabel('PC2 ({:.2%})'.format(variance[1]), fontsize=16)

    for database, color in zip(databases, colors):
        indicesToKeep = pcaDF['activity_classification'] == database
        axes.scatter(pcaDF.loc[indicesToKeep, 'PC1'], pcaDF.loc[indicesToKeep, 'PC2'], c=color, s=5,alpha=0.8)
    axes.legend(databases, fontsize=16,loc='upper left', scatterpoints=5)
    plt.tick_params(labelsize=14)
    #axes.set_xlim(left=-5.2, right=30.5)
    axes.set_yticks([-5,0,5,10,15])
    axes.set_xticks([-5,0,5,10,15])
    #axes.set_ylim(bottom=-11.5, top=37)

    plt.tight_layout()

#     if len(set(pcaDF.db))==2:
#         plt.savefig('../../../20210901_analysis/pca.png')
    plt.show()

# %%
databases = ['Active', 'Inactive']
colors = ['#145c37', '#ebb8dd']
plt.figure(dpi=300)
plot_pca(pcaDF,variance,databases,colors)

# %%
databases = [i for i in reversed(databases)]
colors = reversed(colors)

plot_pca(pcaDF,variance,databases,colors)

# %%
import rdkit
print(rdkit.__version__)
from rdkit import Chem
from rdkit import DataStructs
from rdkit.Chem import Draw
from rdkit.Chem.Draw import IPythonConsole


import numpy as np
import pandas as pd
from rdkit.Chem import rdmolfiles
from rdkit.Chem.rdmolfiles import SmilesMolSupplier
from rdkit.Chem import SDMolSupplier
from rdkit.Chem import AllChem, PandasTools
from rdkit.Chem.FilterCatalog import FilterCatalog, FilterCatalogParams
from rdkit.Chem import SaltRemover
import os
import subprocess
import matplotlib.pyplot as plt

import chembl_structure_pipeline
print(chembl_structure_pipeline.__version__)
# Out:
# 2021.03.2
# 1.0.0
# <frozen importlib._bootstrap>:219: RuntimeWarning: to-Python converter for boost::shared_ptr<RDKit::FilterCatalogEntry const> already registered; second conversion method ignored.

# %%
#train model of the combined data set


#calculate mw and physicochem_properties
import physicochem_properties_for_pca
from rdkit.Chem import Descriptors

PandasTools.AddMoleculeColumnToFrame(overlap,'preprocessedSmiles','Molecule')

def cal_mw(mol):
    return round(Descriptors.MolWt(mol), 3)

overlap['mw'] = overlap.Molecule.apply(cal_mw)
# Out:
# /home/sliu/miniconda3/envs/ringsys/lib/python3.8/site-packages/rdkit/Chem/PandasTools.py:425: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frame[molCol] = frame[smilesCol].map(Chem.MolFromSmiles)
# <ipython-input-31-417d337d6982>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overlap['mw'] = overlap.Molecule.apply(cal_mw)

# %%
descriptors_list = [x[0] for x in Descriptors._descList]
print(descriptors_list)
print(len(descriptors_list))
# Out:
# ['MaxEStateIndex', 'MinEStateIndex', 'MaxAbsEStateIndex', 'MinAbsEStateIndex', 'qed', 'MolWt', 'HeavyAtomMolWt', 'ExactMolWt', 'NumValenceElectrons', 'NumRadicalElectrons', 'MaxPartialCharge', 'MinPartialCharge', 'MaxAbsPartialCharge', 'MinAbsPartialCharge', 'FpDensityMorgan1', 'FpDensityMorgan2', 'FpDensityMorgan3', 'BCUT2D_MWHI', 'BCUT2D_MWLOW', 'BCUT2D_CHGHI', 'BCUT2D_CHGLO', 'BCUT2D_LOGPHI', 'BCUT2D_LOGPLOW', 'BCUT2D_MRHI', 'BCUT2D_MRLOW', 'BalabanJ', 'BertzCT', 'Chi0', 'Chi0n', 'Chi0v', 'Chi1', 'Chi1n', 'Chi1v', 'Chi2n', 'Chi2v', 'Chi3n', 'Chi3v', 'Chi4n', 'Chi4v', 'HallKierAlpha', 'Ipc', 'Kappa1', 'Kappa2', 'Kappa3', 'LabuteASA', 'PEOE_VSA1', 'PEOE_VSA10', 'PEOE_VSA11', 'PEOE_VSA12', 'PEOE_VSA13', 'PEOE_VSA14', 'PEOE_VSA2', 'PEOE_VSA3', 'PEOE_VSA4', 'PEOE_VSA5', 'PEOE_VSA6', 'PEOE_VSA7', 'PEOE_VSA8', 'PEOE_VSA9', 'SMR_VSA1', 'SMR_VSA10', 'SMR_VSA2', 'SMR_VSA3', 'SMR_VSA4', 'SMR_VSA5', 'SMR_VSA6', 'SMR_VSA7', 'SMR_VSA8', 'SMR_VSA9', 'SlogP_VSA1', 'SlogP_VSA10', 'SlogP_VSA11', 'S
# ...

# %%
from rdkit.ML.Descriptors import MoleculeDescriptors
def compute_2Drdkit(mol):
    calc = MoleculeDescriptors.MolecularDescriptorCalculator([x[0] for x in Descriptors._descList])
    ds = calc.CalcDescriptors(mol)
    return list(ds)

# %%
overlap['descriptor'] = overlap.Molecule.apply(compute_2Drdkit)
# Out:
# <ipython-input-34-8ec3164ca733>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overlap['descriptor'] = overlap.Molecule.apply(compute_2Drdkit)

# %%
overlap
# Out:
#                                      preprocessedSmiles            id  \
# 0                         Brc1ccc2c(c1)CCC2=Cc1c[nH]cn1  CHEMBL174579
# 1                  O=c1cc(-c2ccc(O)cc2)oc2cc(O)cc(O)c12      CHEMBL28
# 2                         COc1ccc2cc(-c3cccnc3)ccc2c1Br  CHEMBL196328
# 3            CC[CH]1CC2C(CCC3(C)C(O)CCC23)C2(C)CCCC=C12  CHEMBL306022
# 4                 COc1ccc2nc3cc(Cl)ccc3c(Nc3cccnc3)c2c1  CHEMBL495567
# ...                                                 ...           ...
# 4638  CS(=O)(=O)c1ccc(C(=O)C2C(=O)CCCC2=O)c([N+](=O)...   144214011.0
# 4639                         O=C(O)COc1nc(Cl)c(Cl)cc1Cl   144214034.0
# 4640             COc1ccc(C(c2ccc(OC)cc2)C(Cl)(Cl)Cl)cc1   144214036.0
# 4641                     CCCCC(CC)COC(=O)c1ccccc1C(=O)O   144214037.0
# 4642           CCCCC(CC)COC(=O)c1ccccc1C(=O)OCC(CC)CCCC   144214045.0
#
#      activity_classification  \
# 0                        NaN
# 1                        NaN
# 2                        NaN
# ...

# %%
#one descriptor per column
calc = MoleculeDescriptors.MolecularDescriptorCalculator([x[0] for x in Descriptors._descList])
desc_cols = list(calc.GetDescriptorNames())
overlap[desc_cols] = overlap.descriptor.to_list()
# Out:
# <ipython-input-36-e937a37fd6c1>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overlap[desc_cols] = overlap.descriptor.to_list()
# /home/sliu/miniconda3/envs/ringsys/lib/python3.8/site-packages/pandas/core/indexing.py:1738: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)

# %%
overlap[desc_cols].describe()
# Out:
#        MaxEStateIndex  MinEStateIndex  MaxAbsEStateIndex  MinAbsEStateIndex  \
# count     4622.000000     4622.000000        4622.000000        4622.000000
# mean        11.123957       -1.167730          11.123957           0.218714
# std          2.786758        1.690211           2.786758           0.421017
# min          2.203562       -9.769375           2.203562           0.000000
# 25%         10.579033       -1.607494          10.579033           0.043854
# 50%         12.059112       -0.559378          12.059112           0.110779
# 75%         12.760240       -0.087148          12.760240           0.249819
# max         17.442653        1.369141          17.442653           8.764932
#
#                qed        MolWt  HeavyAtomMolWt   ExactMolWt  \
# count  4622.000000  4622.000000     4622.000000  4622.000000
# mean      0.564708   370.359407      347.574725   369.885844
# std       0.213513   112.691540      107.045169   112.566047
# ...

# %%
overlap[desc_cols].dropna(inplace=True)
# Out:
# <ipython-input-38-8d32505d6321>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overlap[desc_cols].dropna(inplace=True)

# %%
overlap[desc_cols].isnull().values.any()
# Out:
# True

# %%
overlap.iloc[1505,:] #NO idea why
# Out:
# preprocessedSmiles         NC1[CH]2CN(c3nc4c(cc3F)c(=O)c(C(=O)O)cn4-c3ccc...
# id                                                               144204531.0
# activity_classification                                               Active
# Molecule                   <img data-content="rdkit/molecule" src="data:i...
# N                                                                          4
#                                                  ...
# fr_thiazole                                                                0
# fr_thiocyan                                                                0
# fr_thiophene                                                               0
# fr_unbrch_alkane                                                           0
# fr_urea                                                                    0
# Name: 1508, Length: 229, dtype: object

# %%
overlap.drop(labels=1505, axis=0,inplace=True)
# Out:
# /home/sliu/miniconda3/envs/ringsys/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
overlap.reset_index(inplace=True)

# %%
overlap.reset_index(inplace=True)
overlap.loc[overlap['activity_classification']== 'Active', 'y_ture_lable'] = 1
overlap.loc[overlap['activity_classification']== 'Inactive', 'y_ture_lable'] = 0
# Out:
# /home/sliu/miniconda3/envs/ringsys/lib/python3.8/site-packages/pandas/core/indexing.py:1599: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# /home/sliu/miniconda3/envs/ringsys/lib/python3.8/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
#RF classifier
#ROC with cross validation
import sklearn
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import auc
from sklearn.metrics import RocCurveDisplay
from sklearn.model_selection import StratifiedKFold

from sklearn import preprocessing
from sklearn.ensemble import RandomForestClassifier
from imblearn.over_sampling import SMOTE,SMOTENC
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score, matthews_corrcoef, cohen_kappa_score, plot_roc_curve, plot_confusion_matrix # model stats

import pickle
print(sklearn.__version__)
import joblib

from rdkit import Chem
from rdkit.ML.Scoring.Scoring import CalcBEDROC
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-44-e36fc2fcbb0c> in <module>
#      12 from sklearn import preprocessing
#      13 from sklearn.ensemble import RandomForestClassifier
# ---> 14 from imblearn.over_sampling import SMOTE,SMOTENC
#      15 from sklearn.model_selection import train_test_split
#      16 from sklearn.metrics import roc_auc_score, matthews_corrcoef, cohen_kappa_score, plot_roc_curve, plot_confusion_matrix # model stats
#
# ModuleNotFoundError: No module named 'imblearn'

# %%
def roc_cv(X,y):
    cv = StratifiedKFold(n_splits=10)
    classifier = RandomForestClassifier(n_estimators=1000,class_weight='balanced', max_features='sqrt', 
                                        min_samples_split=2, random_state=42)
                                        #max_features and min_samples_split are actually equal to default

    tprs = []
    aucs = []
    mean_fpr = np.linspace(0, 1, 100)
    BEDROC = []

    fig, ax = plt.subplots()
    for i, (train, test) in enumerate(cv.split(X, y)):
        classifier.fit(X[train], y[train])
        #viz = RocCurveDisplay.from_estimator(
        viz = plot_roc_curve(
            classifier,
            X[test],
            y[test],
            name="ROC fold {}".format(i),
            alpha=0.3,
            lw=1,
            ax=ax,
        )
        interp_tpr = np.interp(mean_fpr, viz.fpr, viz.tpr)
        interp_tpr[0] = 0.0
        tprs.append(interp_tpr)
        aucs.append(viz.roc_auc)
        
        # Get predicted probabilities and true labels for test set
        y_prob = classifier.predict_proba(X[test])
        #y_pred = classifier.predict(X[test])
       
        score = list(zip(y_prob[:, 1], y[test]))
        score.sort(key=lambda x: x[0], reverse=True)
        print(score)
        bedroc_score = CalcBEDROC(score, 1, 80.5)
        BEDROC.append(bedroc_score)
        

    print(BEDROC)
    mean_bedroc = np.mean(BEDROC)
    std_bedroc = np.std(BEDROC)
    print("BEDROC: {:.3f} +/- {:.3f}".format(mean_bedroc, std_bedroc))

    
    ax.plot([0, 1], [0, 1], linestyle="--", lw=2, color="r", label="Chance", alpha=0.8)

    mean_tpr = np.mean(tprs, axis=0)
    mean_tpr[-1] = 1.0
    mean_auc = auc(mean_fpr, mean_tpr)
    std_auc = np.std(aucs)
    ax.plot(
        mean_fpr,
        mean_tpr,
        color="b",
        label=r"Mean ROC (AUC = %0.2f $\pm$ %0.2f)" % (mean_auc, std_auc),
        lw=2,
        alpha=0.8,
    )

    std_tpr = np.std(tprs, axis=0)
    tprs_upper = np.minimum(mean_tpr + std_tpr, 1)
    tprs_lower = np.maximum(mean_tpr - std_tpr, 0)
    ax.fill_between(
        mean_fpr,
        tprs_lower,
        tprs_upper,
        color="grey",
        alpha=0.2,
        label=r"$\pm$ 1 std. dev.",
    )

    ax.set(
        xlim=[-0.05, 1.05],
        ylim=[-0.05, 1.05],
        title="Receiver operating characteristic example",
    )
    ax.legend(loc="lower right")
    plt.show()

    #return probas, labels, tprs, aucs

# %%
X = overlap[desc_cols]
y = overlap.y_ture_lable

# %%
scaler = preprocessing.StandardScaler().fit(X)
X_scaled = scaler.transform(X)

# %%
#combine the train and test set for model

combined_model = RandomForestClassifier(n_estimators=1000,class_weight='balanced', max_features='sqrt', 
                                        min_samples_split=2, random_state=42).fit(X_scaled, y)
joblib.dump(combined_model, f'combined_rdkit2D.joblib')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-153-fa620698010a> in <module>
#       1 #combine the train and test set for model
#       2
# ----> 3 combined_model = RandomForestClassifier(n_estimators=1000,class_weight='balanced', max_features='sqrt',
#       4                                         min_samples_split=2, random_state=42).fit(X_scaled, y)
#       5 joblib.dump(combined_model, f'combined_rdkit2D.joblib')
#
# ~/miniconda3/envs/ringsys/lib/python3.8/site-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     302                 "sparse multilabel-indicator for y is not supported."
#     303             )
# --> 304         X, y = self._validate_data(X, y, multi_output=True,
#     305                                    accept_sparse="csc", dtype=DTYPE)
#     306         if sample_weight is not None:
#
# ...

# %%
roc_cv(X_scaled,y)
# Out:
# [(0.996, 1.0), (0.995, 1.0), (0.994, 1.0), (0.993, 1.0), (0.993, 1.0), (0.99, 1.0), (0.987, 1.0), (0.985, 1.0), (0.984, 1.0), (0.984, 1.0), (0.982, 1.0), (0.978, 1.0), (0.97, 1.0), (0.9678373185901865, 0.0), (0.967, 0.0), (0.9667201616737994, 1.0), (0.966, 1.0), (0.966, 1.0), (0.9659114571579026, 1.0), (0.963, 1.0), (0.963, 1.0), (0.9618373185901865, 1.0), (0.957557480263986, 1.0), (0.956, 1.0), (0.956, 1.0), (0.951, 1.0), (0.95, 1.0), (0.9479092092824514, 0.0), (0.947, 1.0), (0.9455626973806427, 0.0), (0.939, 1.0), (0.935, 0.0), (0.933, 0.0), (0.933, 0.0), (0.9327201616737993, 1.0), (0.932, 1.0), (0.927631618831702, 1.0), (0.9271892458286954, 0.0), (0.923, 1.0), (0.919, 1.0), (0.919, 1.0), (0.914, 1.0), (0.909378491657391, 0.0), (0.908, 1.0), (0.9075626973806428, 0.0), (0.9068853273577553, 1.0), (0.906, 1.0), (0.905, 1.0), (0.903, 1.0), (0.9025599645381284, 0.0), (0.9012828590544422, 0.0), (0.899, 1.0), (0.896, 1.0), (0.895, 1.0), (0.8938373185901867, 1.0), (0.892, 1.0), (0.89072016
# ...

# %%
#Morgan2 FP
def get_morgan2(mol):
    return list(AllChem.GetMorganFingerprintAsBitVect(mol,2,nBits=2048))

# %%
overlap['fp'] = overlap.Molecule.apply(get_morgan2) #doesn't work if save the fp in one column
# Out:
# <ipython-input-98-90dd97ebe758>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overlap['fp'] = overlap.Molecule.apply(get_morgan2) #doesn't work if save the fp in one column

# %%
morgan2_cols = ['morgan2_b'+str(i) for i in list(range(2048))]
overlap[morgan2_cols] = overlap.fp.to_list()
# Out:
# <ipython-input-99-4b78ad24ceff>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overlap[morgan2_cols] = overlap.fp.to_list()
# /home/sliu/miniconda3/envs/ringsys/lib/python3.8/site-packages/pandas/core/indexing.py:1738: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)

# %%
X = overlap[morgan2_cols]
y = overlap.y_ture_lable

# %%
roc_cv(np.array(X),y)
# Out:
# [(0.999, 1.0), (0.998, 1.0), (0.997, 1.0), (0.997, 1.0), (0.996, 1.0), (0.996, 1.0), (0.996, 1.0), (0.996, 1.0), (0.993, 1.0), (0.993, 1.0), (0.992, 1.0), (0.992, 1.0), (0.99, 1.0), (0.99, 1.0), (0.99, 1.0), (0.99, 1.0), (0.987, 1.0), (0.987, 1.0), (0.986, 1.0), (0.986, 1.0), (0.986, 1.0), (0.985, 1.0), (0.984, 1.0), (0.983, 1.0), (0.982, 1.0), (0.981, 1.0), (0.979, 1.0), (0.979, 1.0), (0.976, 1.0), (0.975, 0.0), (0.974, 1.0), (0.974, 1.0), (0.972, 1.0), (0.971, 1.0), (0.97, 1.0), (0.967, 1.0), (0.965, 1.0), (0.9615626973806428, 1.0), (0.96, 1.0), (0.958, 1.0), (0.958, 0.0), (0.958, 1.0), (0.957, 1.0), (0.956, 1.0), (0.954, 1.0), (0.9530491710664665, 1.0), (0.953, 1.0), (0.9528853273577552, 1.0), (0.949, 1.0), (0.948, 1.0), (0.947, 1.0), (0.946, 0.0), (0.946, 0.0), (0.945, 1.0), (0.945, 1.0), (0.944, 1.0), (0.942, 1.0), (0.94, 1.0), (0.94, 0.0), (0.9393914954116583, 0.0), (0.938, 1.0), (0.933, 0.0), (0.931, 1.0), (0.926, 1.0), (0.924, 0.0), (0.923, 0.0), (0.923, 0.0), (0.922, 0.0), (
# ...

# %%
#combine the train and test set for model

combined_model = RandomForestClassifier(n_estimators=1000,class_weight='balanced', max_features='sqrt', 
                                        min_samples_split=2, random_state=42).fit(np.array(X), y)
joblib.dump(combined_model, f'combined_morgan2fp.joblib')
# Out:
# ['combined_morgan2fp.joblib']

# %%
#rdkit2d+fp
desc_cols_combined = desc_cols + morgan2_cols
len(desc_cols_combined)
X_combined = overlap[desc_cols_combined]
y = overlap.y_ture_lable
roc_cv(np.array(X_combined),y)
# Out:
# [(0.996, 1.0), (0.995, 1.0), (0.9947201616737993, 1.0), (0.994, 1.0), (0.994, 1.0), (0.992, 1.0), (0.992, 1.0), (0.991, 1.0), (0.988, 1.0), (0.987, 1.0), (0.983, 1.0), (0.982, 1.0), (0.982, 1.0), (0.981, 1.0), (0.981, 1.0), (0.98, 1.0), (0.976, 1.0), (0.971, 1.0), (0.97, 1.0), (0.969, 1.0), (0.969, 1.0), (0.967, 1.0), (0.967, 1.0), (0.966, 1.0), (0.965, 1.0), (0.962, 1.0), (0.962, 0.0), (0.957, 1.0), (0.956, 1.0), (0.95, 1.0), (0.95, 1.0), (0.94988313096934, 1.0), (0.949, 1.0), (0.948, 1.0), (0.946, 0.0), (0.944, 1.0), (0.939, 1.0), (0.938, 1.0), (0.937, 1.0), (0.936, 1.0), (0.935, 0.0), (0.934, 0.0), (0.93, 1.0), (0.93, 1.0), (0.928, 1.0), (0.925, 1.0), (0.922, 0.0), (0.9193517805055014, 0.0), (0.916, 1.0), (0.911, 1.0), (0.9078373185901866, 1.0), (0.9046054890315546, 1.0), (0.903, 1.0), (0.9026317655647096, 1.0), (0.8997201616737993, 1.0), (0.8985574802639859, 0.0), (0.898, 0.0), (0.898, 1.0), (0.897, 1.0), (0.895, 0.0), (0.8884566097653458, 1.0), (0.883, 1.0), (0.881, 0.0), (0.877
# ...

# %%
#combine the train and test set for model

combined_model = RandomForestClassifier(n_estimators=1000,class_weight='balanced', max_features='sqrt', 
                                        min_samples_split=2, random_state=42).fit(np.array(X_combined), y)
joblib.dump(combined_model, f'combined_rdkit2d_morgan2fp.joblib')
# Out:
# ['combined_rdkit2d_morgan2fp.joblib']
